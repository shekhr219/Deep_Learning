# %% [markdown]
# # Simple GPT on TinyShakespeare Dataset

# %%
# getting the tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2024-04-14 12:57:05--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.05s
#
# 2024-04-14 12:57:05 (21.9 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %% [markdown]
# ### EDA

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  1115394

# %%
print(text[:2000])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.
#
# Second Citizen:
# Would you proceed especially against Caius Marcius?
#
# All:
# Against him first: he's a very dog to the commonalty.
#
# Second Citizen:
# Consider you what services he has done for his country?
#
# First Citizen:
# Very well; and could be content to give him good
# report fort, but that he pays himself with being proud.
#
# Second Citizen:
# Nay, but speak not maliciously.
#
# First Citizen:
# I say unto you, what he hath done famously, he did
# it to that end: though soft-conscienced men can be
# content to say it was for his country he did it to
# please his mother and to be partly proud; which he
# is, even till the altitude of his virtue.
#
# Second Citizen:
# What he cannot help in his nature, you account a
# vice in him. You must in no way say he is covetous.
#
# First Citizen:
# If I must not, I need not be barren of accusations;
# he hath faults, with surplus, to tire in repetition.
# What shouts are these? The other side o' the city
# is risen: why stay we prating here? to the Capitol!
#
# All:
# Come, come.
#
# First C

# %% [markdown]
# ### Model Training
# Trained for 7000 iterations and evaluated in an interval of 50

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 7000
eval_interval = 50
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []
step = []
for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_loss = losses['train']
        val_loss = losses['val']
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        step.append(iter)
    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 50: train loss 2.9484, val loss 2.9807
# step 100: train loss 2.6600, val loss 2.6659
# step 150: train loss 2.5598, val loss 2.5786
# step 200: train loss 2.5119, val loss 2.5150
# step 250: train loss 2.4611, val loss 2.4612
# step 300: train loss 2.4030, val loss 2.4183
# step 350: train loss 2.3706, val loss 2.3757
# step 400: train loss 2.3436, val loss 2.3495
# step 450: train loss 2.3250, val loss 2.3411
# step 500: train loss 2.2947, val loss 2.2948
# step 550: train loss 2.2803, val loss 2.2820
# step 600: train loss 2.2343, val loss 2.2485
# step 650: train loss 2.2294, val loss 2.2422
# step 700: train loss 2.1952, val loss 2.2119
# step 750: train loss 2.1733, val loss 2.2023
# step 800: train loss 2.1612, val loss 2.1835
# step 850: train loss 2.1406, val loss 2.1778
# step 900: train loss 2.1282, val loss 2.1562
# step 950: train loss 2.1075, val loss 2.1367
# step 1000: train loss 2.0834, val loss 2.1334
# step 1050: train loss 2.0850, val loss 2.1271
# step 1100: train loss 2.0669, val loss 2.1131
# step 1150: train loss 2.0426, val loss 2.1017
# step 1200: train loss 2.0347, val loss 2.0873
# step 1250: train loss 2.0219, val loss 2.0821
# step 1300: train loss 2.0165, val loss 2.0583
# step 1350: train loss 2.0000, val loss 2.0650
# step 1400: train loss 1.9880, val loss 2.0533
# step 1450: train loss 1.9809, val loss 2.0327
# step 1500: train loss 1.9793, val loss 2.0366
# step 1550: train loss 1.9638, val loss 2.0309
# step 1600: train loss 1.9529, val loss 2.0378
# step 1650: train loss 1.9509, val loss 2.0329
# step 1700: train loss 1.9320, val loss 2.0215
# step 1750: train loss 1.9285, val loss 2.0059
# step 1800: train loss 1.9116, val loss 2.0063
# step 1850: train loss 1.9156, val loss 1.9870
# step 1900: train loss 1.9086, val loss 2.0036
# step 1950: train loss 1.8803, val loss 1.9828
# step 2000: train loss 1.8740, val loss 1.9782
# step 2050: train loss 1.8726, val loss 1.9721
# step 2100: train loss 1.8669, val loss 1.9778
# step 2150: train loss 1.8728, val loss 1.9637
# step 2200: train loss 1.8611, val loss 1.9643
# step 2250: train loss 1.8533, val loss 1.9547
# step 2300: train loss 1.8459, val loss 1.9483
# step 2350: train loss 1.8361, val loss 1.9588
# step 2400: train loss 1.8356, val loss 1.9459
# step 2450: train loss 1.8413, val loss 1.9494
# step 2500: train loss 1.8318, val loss 1.9481
# step 2550: train loss 1.8104, val loss 1.9308
# step 2600: train loss 1.8064, val loss 1.9268
# step 2650: train loss 1.8121, val loss 1.9368
# step 2700: train loss 1.8107, val loss 1.9182
# step 2750: train loss 1.8026, val loss 1.9320
# step 2800: train loss 1.7992, val loss 1.9231
# step 2850: train loss 1.7997, val loss 1.9265
# step 2900: train loss 1.7805, val loss 1.9075
# step 2950: train loss 1.7807, val loss 1.9014
# step 3000: train loss 1.7676, val loss 1.9003
# step 3050: train loss 1.7650, val loss 1.8911
# step 3100: train loss 1.7663, val loss 1.9166
# step 3150: train loss 1.7726, val loss 1.8910
# step 3200: train loss 1.7769, val loss 1.9044
# step 3250: train loss 1.7602, val loss 1.9123
# step 3300: train loss 1.7448, val loss 1.8876
# step 3350: train loss 1.7502, val loss 1.8933
# step 3400: train loss 1.7502, val loss 1.8749
# step 3450: train loss 1.7593, val loss 1.8961
# step 3500: train loss 1.7363, val loss 1.8880
# step 3550: train loss 1.7442, val loss 1.8847
# step 3600: train loss 1.7352, val loss 1.8671
# step 3650: train loss 1.7297, val loss 1.8649
# step 3700: train loss 1.7265, val loss 1.8937
# step 3750: train loss 1.7294, val loss 1.8792
# step 3800: train loss 1.7153, val loss 1.8626
# step 3850: train loss 1.7171, val loss 1.8600
# step 3900: train loss 1.7197, val loss 1.8735
# step 3950: train loss 1.7264, val loss 1.8602
# step 4000: train loss 1.7091, val loss 1.8696
# step 4050: train loss 1.7149, val loss 1.8641
# step 4100: train loss 1.7090, val loss 1.8748
# step 4150: train loss 1.6956, val loss 1.8619
# step 4200: train loss 1.7103, val loss 1.8594
# step 4250: train loss 1.7028, val loss 1.8502
# step 4300: train loss 1.7036, val loss 1.8570
# step 4350: train loss 1.7071, val loss 1.8523
# step 4400: train loss 1.6865, val loss 1.8443
# step 4450: train loss 1.6919, val loss 1.8493
# step 4500: train loss 1.6891, val loss 1.8557
# step 4550: train loss 1.6911, val loss 1.8586
# step 4600: train loss 1.6939, val loss 1.8496
# step 4650: train loss 1.6909, val loss 1.8537
# step 4700: train loss 1.6831, val loss 1.8406
# step 4750: train loss 1.6831, val loss 1.8374
# step 4800: train loss 1.6811, val loss 1.8286
# step 4850: train loss 1.6817, val loss 1.8363
# step 4900: train loss 1.6670, val loss 1.8339
# step 4950: train loss 1.6633, val loss 1.8224
# step 5000: train loss 1.6752, val loss 1.8415
# step 5050: train loss 1.6660, val loss 1.8299
# step 5100: train loss 1.6572, val loss 1.8216
# step 5150: train loss 1.6657, val loss 1.8376
# step 5200: train loss 1.6735, val loss 1.8194
# step 5250: train loss 1.6539, val loss 1.8154
# step 5300: train loss 1.6522, val loss 1.8176
# step 5350: train loss 1.6638, val loss 1.8087
# step 5400: train loss 1.6519, val loss 1.8093
# step 5450: train loss 1.6435, val loss 1.8224
# step 5500: train loss 1.6592, val loss 1.8201
# step 5550: train loss 1.6451, val loss 1.8126
# step 5600: train loss 1.6609, val loss 1.8174
# step 5650: train loss 1.6482, val loss 1.8164
# step 5700: train loss 1.6387, val loss 1.8200
# step 5750: train loss 1.6465, val loss 1.8121
# step 5800: train loss 1.6516, val loss 1.8131
# step 5850: train loss 1.6444, val loss 1.8027
# step 5900: train loss 1.6557, val loss 1.8111
# step 5950: train loss 1.6371, val loss 1.8069
# step 6000: train loss 1.6472, val loss 1.8339
# step 6050: train loss 1.6195, val loss 1.7978
# step 6100: train loss 1.6247, val loss 1.8106
# step 6150: train loss 1.6402, val loss 1.8186
# step 6200: train loss 1.6270, val loss 1.8017
# step 6250: train loss 1.6409, val loss 1.8117
# step 6300: train loss 1.6335, val loss 1.7954
# step 6350: train loss 1.6358, val loss 1.8129
# step 6400: train loss 1.6307, val loss 1.7986
# step 6450: train loss 1.6241, val loss 1.7849
# step 6500: train loss 1.6211, val loss 1.7996
# step 6550: train loss 1.6197, val loss 1.7985
# step 6600: train loss 1.6326, val loss 1.7936
# step 6650: train loss 1.6226, val loss 1.7851
# step 6700: train loss 1.6319, val loss 1.8008
# step 6750: train loss 1.6063, val loss 1.7865
# step 6800: train loss 1.6179, val loss 1.7923
# step 6850: train loss 1.6119, val loss 1.7945
# step 6900: train loss 1.6207, val loss 1.7779
# step 6950: train loss 1.6066, val loss 1.7662
# step 6999: train loss 1.6229, val loss 1.7850

# %% [markdown]
# ### Generating from the model
# Generating 3000 chars from the trained model

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=3000)[0].tolist()))
# Out:
# YORK:
# I brid sweath is not thread, to Back in anvirtake me?
# It us barnit help queeh. that dilth a enjweced of himself, zolou:
# You, Lord Citic both! Wholes
# What might send, will is the losts, and Wilt may in want!
# Ill not me little me new by stuppiniss hiwty.
# Here, sence of this love my like tooth keep Willon him evices to them,
# Will chemfied strook of his but pray nobrust for treight!
# Iff threforle of my sad
# When I have rangely harried is:
# Sads by his grest hoilt murder and
# Hire to chan you! who need soke me you see's his
# Than braine his mean; for well threaty thou such me to liegived
# On of courfe's that that lord
# In as he laper the seaze Peace, move maded and
# Lest's coure by some so need six!
# 'TRAKENLI:
# Whith loves, strike, it desecondes our head:
# But a woble from the war so! who live not,
# Whose lady to night, cried is,-help.
# I knot throne not, Celiey
# Be this of time the shower eyest of appriant is be than to could peiely like
# Pontroth'd truth, critht doth York?
#
# Shy Gru;
# To know our hertan: it well, go, I hus need, what not
# A very hear tows to Edward, well should
# Is be rest mines so leads his in infectious,
# The absted, acclain a braned his enInips.
#
# FRORIZAR:
# I let's toak be keep, blaid at my brefoleing breatness whiles; I new, if this lawbly's lest,
# Than Tumlelal pritty coldrest tojest the voicest unto recold
# A master night, stay abolesty doth'd the not church begute
# To cave but need to be the bod; I not,
# I thinke numon my writh enyman.
#
# LUCENTIO:
# Will the farewell! he eselves; for I wrehum happy Rome, every it
# Brut of a-latest my love more of wherefore
# Of ristrare gentlely preive have, ary patry hiph.
#
# BENVORHAMIO:
# Writhd. Thou, as show give ather
# My mahtreaty assio'd; I'll hearth; command then: him wife
# Once frit thy Edwrard's flait's mon lives?
# The leave twretter tong intalk'd of at but the peepose: life he putict
# What is a foe, our know-love, sir, try prozing me,
# I word trongal ature comfort, Julio, pardon.
#
# In Lord Den's from thee suppech you have noble all,; every beliegn, him? Why lord.
#
# DUKE VINCENTIGIO:
# Fight france your subje to tell be
# Birtath: live his sook a well
# than cled love in thee new flow
# sorm of him sisons it is up
# Thip heave its you pew
# And your lord many holy fite tone them them
# All be non shew sad! My lord, I untel some softed my leave
# Ony meance a long approus infliked been,
# Will not can clest a mild, you dand. Well me.
#
# DERCUTIO:
# holy body unone should move cit his-him,
# To that desiry: true hear sleep not teempts
# Meque crown of your call'd to be have to acclity?
#
# Judittion true, good Atwer.
#
# LADY BOLIA:
# We, nevery haven the I had counted,
# It the time truell'd be crumm matter's death;
# Make the courted doth will well.
#
# GREMIO:
# My need; them, Chillw, for you you royalt well,
# On Where, therefulickit shold, Lord but have's
# him take woe heave ignocer to knowly fear of my I luve it Done
# When to nequare as. Yet, if him
# hear thou light drehitting his that be crits? And, knother
# by to Richsated predeable's servicile,
# Who, his t

# %% [markdown]
# ### Plotting the losses

# %%
import matplotlib.pyplot as plt
plt.plot(step, train_losses, label='Train Loss')
plt.plot(step, val_losses, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
